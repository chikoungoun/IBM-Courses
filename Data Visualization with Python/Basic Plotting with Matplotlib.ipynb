# %% [markdown]
# # Basic Plotting with matplotlib

# %%
import matplotlib.pyplot as plt 
# %matplotlib notebook

# %%
plt.plot(5,5,'o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.ylabel('Y')
plt.xlabel('X')
plt.title("Plotting Example")
# Out:
# Text(0.5, 1.0, 'Plotting Example')

# %% [markdown]
# ### Pandas Matplotlib

# %%
import pandas as pd

# %%
d = {'India': [8880,8670,8147,7338,5704],'China':[5123,6682,3308,1863,1527]}

# %%
dates = [1980,1981,1982,1983,1984]

# %%
df= pd.DataFrame(d,index=dates)

# %%
df
# Out:
#       India  China
# 1980   8880   5123
# 1981   8670   6682
# 1982   8147   3308
# 1983   7338   1863
# 1984   5704   1527

# %%
df.plot(kind='line')
# Out:
# <img src="data:image/png;base64,..." width="432">
